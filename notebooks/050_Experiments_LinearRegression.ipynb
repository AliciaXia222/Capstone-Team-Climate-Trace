# %%
import sys
import os
from datetime import datetime
import time
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
pd.set_option('display.max_rows', None)
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sys.path.append(os.path.abspath('../src'))
from lib import (
    get_train_test_split,
    get_trained_model,
    train_and_evaluate_models,
    create_eui_comparison_plots,
    evaluate_model_strategies,
    calculate_average_metrics,
    create_error_distribution_plots
)

# %%
output_path = "../data/03_processed/merged_df.csv"
merged_df = pd.read_csv(output_path)
merged_df = merged_df.rename(columns={'total_year': 'hdd_total_year'})

# GDP per capita
merged_df['GDP_per_capita'] = merged_df['GDP_2022'] / merged_df['Population_2023']

# Delete Taiwan (temporal)
merged_df = merged_df[merged_df['Country'] != 'Taiwan']

np.random.seed(123)
merged_df['is_train'] = np.random.choice([1, 0], size=len(merged_df), p=[0.8, 0.2])

# %%
features = [
    "hdd_total_year", 
    "cdd_total_year", 
    "GDP_per_capita", 
    "Urbanization_Rate_2022",
    "latitude",
    "longitude",  
    "Paris_Agreement",
    "Subnational HDI", 
    "Educational index", 
    "Income index"
]

feature_abbreviations = {
    "hdd_total_year": "HDD",
    "cdd_total_year": "CDD", 
    "GDP_per_capita": "GDP",
    "Urbanization_Rate_2022": "URB",
    "latitude": "Lat",
    "longitude": "Long",
    "Paris_Agreement": "Paris",
    "Subnational HDI": "HDI", 
    "Educational index": "EDU" , 
    "Income index": "Income"
}

target_columns = [
    "Residential EUI (kWh/m2/year)",
    "Non-residential EUI (kWh/m2/year)"
]

regions = ['Asia & Oceania', 'Europe', 'Africa', 'Central and South America', 'Northern America']

# %% [markdown]
# # Linear Regression - Within Domain

# %%
# Within-domain
model_lr_within = LinearRegression()
results_lr_within = train_and_evaluate_models(
    merged_df=merged_df,
    regions=regions, 
    features=features,
    model=model_lr_within,
    strategy='within_domain'
)

create_eui_comparison_plots(results_lr_within, 
    save_path='../figures/lr_within_domain_eui_predictions.png')

# %%
create_error_distribution_plots(results_lr_within,
    save_path='../figures/lr_within_domain_error_distribution.png')

# %% [markdown]
# # Linear Regression - Cross Domain

# %%
# Cross-domain 
model_lr_cross = LinearRegression()
results_lr_cross = train_and_evaluate_models(
    merged_df=merged_df,
    regions=regions,
    features=features, 
    model=model_lr_cross,
    strategy='cross_domain'
)

create_eui_comparison_plots(results_lr_cross,
    save_path='../figures/lr_cross_domain_eui_predictions.png')

# %%
create_error_distribution_plots(results_lr_cross,
    save_path='../figures/lr_cross_domain_error_distribution.png')

# %% [markdown]
# # Linear Regression - All Domain

# %%
# All-domain
model_lr_all = LinearRegression()
results_lr_all = train_and_evaluate_models(
    merged_df=merged_df,
    regions=regions,
    features=features,
    model=model_lr_all, 
    strategy='all_domain'
)

create_eui_comparison_plots(results_lr_all,
    save_path='../figures/lr_all_domain_eui_predictions.png')

# %%
create_error_distribution_plots(results_lr_all,
    save_path='../figures/lr_all_domain_error_distribution.png')

# %%
lr_detailed_results = evaluate_model_strategies(
   merged_df=merged_df,
   regions=regions,
   features=features,
   model_type=LinearRegression,
   feature_abbreviations=feature_abbreviations,
   model_details="No regularization"
)
lr_detailed_results
# Out:
#                        Region                             Target  \
# 0              Asia & Oceania      Residential EUI (kWh/m2/year)
# 1              Asia & Oceania  Non-residential EUI (kWh/m2/year)
# 2                      Europe      Residential EUI (kWh/m2/year)
# 3                      Europe  Non-residential EUI (kWh/m2/year)
# 4                      Africa      Residential EUI (kWh/m2/year)
# 5                      Africa  Non-residential EUI (kWh/m2/year)
# 6   Central and South America      Residential EUI (kWh/m2/year)
# 7   Central and South America  Non-residential EUI (kWh/m2/year)
# 8            Northern America      Residential EUI (kWh/m2/year)
# 9            Northern America  Non-residential EUI (kWh/m2/year)
# 10             Asia & Oceania      Residential EUI (kWh/m2/year)
# 11             Asia & Oceania  Non-residential EUI (kWh/m2/year)
# 12                     Europe      Residential EUI (kWh/m2/year)
# 13                     Europe  Non-residential EUI (kWh/m2/year)
# 14                     Africa      Residential EUI (kWh/m2/year)
# 15                     Africa  Non-residential EUI (kWh/m2/year)
# 16  Central and South America      Residential EUI (kWh/m2/year)
# 17  Central and South America  Non-residential EUI (kWh/m2/year)
# 18           Northern America      Residential EUI (kWh/m2/year)
# 19           Northern America  Non-residential EUI (kWh/m2/year)
# 20             Asia & Oceania      Residential EUI (kWh/m2/year)
# 21             Asia & Oceania  Non-residential EUI (kWh/m2/year)
# 22                     Europe      Residential EUI (kWh/m2/year)
# 23                     Europe  Non-residential EUI (kWh/m2/year)
# 24                     Africa      Residential EUI (kWh/m2/year)
# 25                     Africa  Non-residential EUI (kWh/m2/year)
# 26  Central and South America      Residential EUI (kWh/m2/year)
# 27  Central and South America  Non-residential EUI (kWh/m2/year)
# 28           Northern America      Residential EUI (kWh/m2/year)
# 29           Northern America  Non-residential EUI (kWh/m2/year)
#
#          Strategy             Model      Model Details  \
# 0   within_domain  LinearRegression  No regularization
# 1   within_domain  LinearRegression  No regularization
# 2   within_domain  LinearRegression  No regularization
# 3   within_domain  LinearRegression  No regularization
# 4   within_domain  LinearRegression  No regularization
# 5   within_domain  LinearRegression  No regularization
# 6   within_domain  LinearRegression  No regularization
# 7   within_domain  LinearRegression  No regularization
# 8   within_domain  LinearRegression  No regularization
# 9   within_domain  LinearRegression  No regularization
# 10   cross_domain  LinearRegression  No regularization
# 11   cross_domain  LinearRegression  No regularization
# 12   cross_domain  LinearRegression  No regularization
# 13   cross_domain  LinearRegression  No regularization
# 14   cross_domain  LinearRegression  No regularization
# 15   cross_domain  LinearRegression  No regularization
# 16   cross_domain  LinearRegression  No regularization
# 17   cross_domain  LinearRegression  No regularization
# 18   cross_domain  LinearRegression  No regularization
# 19   cross_domain  LinearRegression  No regularization
# 20     all_domain  LinearRegression  No regularization
# 21     all_domain  LinearRegression  No regularization
# 22     all_domain  LinearRegression  No regularization
# 23     all_domain  LinearRegression  No regularization
# 24     all_domain  LinearRegression  No regularization
# 25     all_domain  LinearRegression  No regularization
# 26     all_domain  LinearRegression  No regularization
# 27     all_domain  LinearRegression  No regularization
# 28     all_domain  LinearRegression  No regularization
# 29     all_domain  LinearRegression  No regularization
#
#                                         Features Used  \
# 0   hdd_total_year, cdd_total_year, GDP_per_capita...
# 1   hdd_total_year, cdd_total_year, GDP_per_capita...
# 2   hdd_total_year, cdd_total_year, GDP_per_capita...
# 3   hdd_total_year, cdd_total_year, GDP_per_capita...
# 4   hdd_total_year, cdd_total_year, GDP_per_capita...
# 5   hdd_total_year, cdd_total_year, GDP_per_capita...
# 6   hdd_total_year, cdd_total_year, GDP_per_capita...
# 7   hdd_total_year, cdd_total_year, GDP_per_capita...
# 8   hdd_total_year, cdd_total_year, GDP_per_capita...
# 9   hdd_total_year, cdd_total_year, GDP_per_capita...
# 10  hdd_total_year, cdd_total_year, GDP_per_capita...
# 11  hdd_total_year, cdd_total_year, GDP_per_capita...
# 12  hdd_total_year, cdd_total_year, GDP_per_capita...
# 13  hdd_total_year, cdd_total_year, GDP_per_capita...
# 14  hdd_total_year, cdd_total_year, GDP_per_capita...
# 15  hdd_total_year, cdd_total_year, GDP_per_capita...
# 16  hdd_total_year, cdd_total_year, GDP_per_capita...
# 17  hdd_total_year, cdd_total_year, GDP_per_capita...
# 18  hdd_total_year, cdd_total_year, GDP_per_capita...
# 19  hdd_total_year, cdd_total_year, GDP_per_capita...
# 20  hdd_total_year, cdd_total_year, GDP_per_capita...
# 21  hdd_total_year, cdd_total_year, GDP_per_capita...
# 22  hdd_total_year, cdd_total_year, GDP_per_capita...
# 23  hdd_total_year, cdd_total_year, GDP_per_capita...
# 24  hdd_total_year, cdd_total_year, GDP_per_capita...
# 25  hdd_total_year, cdd_total_year, GDP_per_capita...
# 26  hdd_total_year, cdd_total_year, GDP_per_capita...
# 27  hdd_total_year, cdd_total_year, GDP_per_capita...
# 28  hdd_total_year, cdd_total_year, GDP_per_capita...
# 29  hdd_total_year, cdd_total_year, GDP_per_capita...
#
#                                  Features Abbreviated        MSE     RMSE  \
# 0   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    950.337   30.828
# 1   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    941.421   30.683
# 2   HDD | CDD | GDP | URB | Lat | Long | Paris | H...   6790.801   82.406
# 3   HDD | CDD | GDP | URB | Lat | Long | Paris | H...   9551.068   97.730
# 4   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    179.656   13.404
# 5   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    151.796   12.321
# 6   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    113.805   10.668
# 7   HDD | CDD | GDP | URB | Lat | Long | Paris | H...     82.925    9.106
# 8   HDD | CDD | GDP | URB | Lat | Long | Paris | H...    935.099   30.579
# 9   HDD | CDD | GDP | URB | Lat | Long | Paris | H...   4611.826   67.910
# 10  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   2145.938   46.324
# 11  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   1774.007   42.119
# 12  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   4341.726   65.892
# 13  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   3101.775   55.694
# 14  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   1301.908   36.082
# 15  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   2092.243   45.741
# 16  HDD | CDD | GDP | URB | Lat | Long | Paris | H...    963.180   31.035
# 17  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   1422.785   37.720
# 18  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   3463.979   58.856
# 19  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  18904.520  137.494
# 20  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   1045.118   32.328
# 21  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   1251.553   35.377
# 22  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   2670.840   51.680
# 23  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   3096.717   55.648
# 24  HDD | CDD | GDP | URB | Lat | Long | Paris | H...    556.471   23.590
# 25  HDD | CDD | GDP | URB | Lat | Long | Paris | H...    501.444   22.393
# 26  HDD | CDD | GDP | URB | Lat | Long | Paris | H...    332.307   18.229
# 27  HDD | CDD | GDP | URB | Lat | Long | Paris | H...    197.457   14.052
# 28  HDD | CDD | GDP | URB | Lat | Long | Paris | H...   2687.847   51.844
# 29  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  12778.478  113.042
#
#         MAE      R²  MAPE  WAPE
# 0    20.588   0.548  25.6  23.3
# 1    21.135   0.599  14.5  14.8
# 2    59.319  -1.164  44.0  30.6
# 3    63.985  -1.200  38.4  27.2
# 4     7.200  -0.090   8.8   9.7
# 5     5.176   0.035   8.4   5.0
# 6     8.723  -0.075  11.9  11.6
# 7     6.752  -1.049   6.3   6.4
# 8    22.546   0.385  11.5  13.3
# 9    60.215  -1.426  21.1  22.1
# 10   40.975  -0.021  66.7  46.3
# 11   29.898   0.245  19.1  21.0
# 12   51.941  -0.384  33.3  26.8
# 13   41.545   0.286  21.2  17.6
# 14   27.314  -6.896  35.0  36.8
# 15   38.410 -12.302  39.4  37.1
# 16   27.127  -8.101  37.8  36.2
# 17   34.455 -34.151  33.2  32.5
# 18   54.337  -1.279  31.0  32.1
# 19  135.050  -8.943  49.4  49.7
# 20   22.066   0.503  33.1  24.9
# 21   22.249   0.468  14.1  15.6
# 22   42.363   0.149  27.5  21.9
# 23   42.023   0.287  21.5  17.8
# 24   15.887  -2.375  19.4  21.4
# 25   18.252  -2.188  20.5  17.6
# 26   14.930  -2.140  21.3  19.9
# 27   11.974  -3.878  11.7  11.3
# 28   46.208  -0.768  25.8  27.3
# 29  109.397  -5.721  39.6  40.2

# %%
lr_average_results = calculate_average_metrics(lr_detailed_results).reset_index()
lr_average_results.sort_values(by='Strategy', ascending=False)
# Out:
#                               Target       Strategy             Model  \
# 0  Non-residential EUI (kWh/m2/year)  within_domain  LinearRegression
# 3      Residential EUI (kWh/m2/year)  within_domain  LinearRegression
# 1  Non-residential EUI (kWh/m2/year)   cross_domain  LinearRegression
# 4      Residential EUI (kWh/m2/year)   cross_domain  LinearRegression
# 2  Non-residential EUI (kWh/m2/year)     all_domain  LinearRegression
# 5      Residential EUI (kWh/m2/year)     all_domain  LinearRegression
#
#        Model Details                                      Features Used  \
# 0  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
# 3  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
# 1  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
# 4  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
# 2  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
# 5  No regularization  hdd_total_year, cdd_total_year, GDP_per_capita...
#
#                                 Features Abbreviated   MAPE      R²       MSE  \
# 0  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  17.74  -0.608  3067.807
# 3  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  20.36  -0.079  1793.940
# 1  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  32.46 -10.973  5459.066
# 4  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  40.76  -3.336  2443.346
# 2  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  21.48  -2.206  3565.130
# 5  HDD | CDD | GDP | URB | Lat | Long | Paris | H...  25.42  -0.926  1458.517
#
#      RMSE     MAE   WAPE
# 0  43.550  31.453  15.10
# 3  33.577  23.675  17.70
# 1  63.754  55.872  31.58
# 4  47.638  40.339  35.64
# 2  48.102  40.779  20.50
# 5  35.534  28.291  23.08

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
lr_detailed_results.to_csv(f'../results/{timestamp}_lr_detailed_results.csv')
lr_average_results.to_csv(f'../results/{timestamp}_lr_average_results.csv')
