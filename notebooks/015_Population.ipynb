# %%
import gdown
import os
import zipfile

import rasterio
import numpy as np
from tqdm import tqdm
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from datetime import datetime
import pandas as pd

# %% [markdown]
# # Country Data

# %%
countries_zip_url = "https://drive.google.com/uc?id=1UQzdO7suT0BnwKBeNybMG97vM9GIDogA"
countries_zip_file_path = "../../allCountries.zip"

# Download the ZIP file if it doesn't exist; otherwise, proceed to read the TXT file.
if not os.path.exists(countries_zip_file_path):
    gdown.download(countries_zip_url, countries_zip_file_path, quiet=False)

with zipfile.ZipFile(countries_zip_file_path) as z:
    countries_txt_filename = "allCountries.txt"

    with z.open(countries_txt_filename) as txt_file:
        countries_df = pd.read_csv(txt_file, sep="\t", header=None)


# https://download.geonames.org/export/dump/
countries_df.columns = [
    'geonameid',         
    'name',             
    'asciiname',        
    'alternatenames',  
    'latitude',         
    'longitude',       
    'feature class',    
    'feature code',      
    'iso alpha 2',      
    'cc2',              
    'admin1 code',     
    'admin2 code',       
    'admin3 code',      
    'admin4 code',   
    'population',      
    'elevation',       
    'dem',             
    'timezone',          
    'modification date'  
]

print(f"\nshape: {countries_df.shape}")
countries_df.head()
# Out:
# /var/folders/9m/ym86jvl93wq3tx6ssy8ql7kh0000gn/T/ipykernel_54567/49276498.py:12: DtypeWarning: Columns (9,10,11,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   countries_df = pd.read_csv(txt_file, sep="\t", header=None)
# shape: (12950185, 19)
#    geonameid                          name                     asciiname  \
# 0    2994701                     Roc Meler                     Roc Meler
# 1    3017832          Pic de les Abelletes          Pic de les Abelletes
# 2    3017833       Estany de les Abelletes       Estany de les Abelletes
# 3    3023203  Port Vieux de la Coume d’Ose  Port Vieux de la Coume d'Ose
# 4    3029315          Port de la Cabanette          Port de la Cabanette
#
#                                       alternatenames  latitude  longitude  \
# 0                        Roc Mele,Roc Meler,Roc Mélé  42.58765    1.74180
# 1  Pic de la Font-Negre,Pic de la Font-Nègre,Pic ...  42.52535    1.73343
# 2  Estany de les Abelletes,Etang de Font-Negre,Ét...  42.52915    1.73362
# 3  Port Vieux de Coume d'Ose,Port Vieux de Coume ...  42.62568    1.61823
# 4     Port de la Cabanette,Porteille de la Cabanette  42.60000    1.73333
#
#   feature class feature code iso alpha 2    cc2 admin1 code admin2 code  \
# 0             T           PK          AD  AD,FR          02         NaN
# 1             T           PK          AD     FR          A9          66
# 2             H           LK          AD     FR          A9         NaN
# 3             T         PASS          AD    NaN          00         NaN
# 4             T         PASS          AD  AD,FR          B3          09
#
#   admin3 code admin4 code  population  elevation   dem        timezone  \
# 0         NaN         NaN           0     2811.0  2348  Europe/Andorra
# 1       663.0     66146.0           0        NaN  2411  Europe/Andorra
# 2         NaN         NaN           0        NaN  2260  Europe/Andorra
# 3         NaN         NaN           0        NaN  2687  Europe/Andorra
# 4        91.0      9139.0           0        NaN  2379  Europe/Andorra
#
#   modification date
# 0        2023-10-03
# 1        2014-11-05
# 2        2014-11-05
# 3        2014-11-05
# 4        2014-11-05

# %% [markdown]
# ## EUI

# %%
eui_url = "https://drive.google.com/uc?id=12qGq_DLefI1RihIF_RKQUyJtm480-xRC"
eui_df = pd.read_csv(eui_url)

print(f"shape: {eui_df.shape}")
eui_df.head()
# Out:
# shape: (482, 5)
#          City  Geonames ID               Country  \
# 0   Nha Trang      1572151               Vietnam
# 1    Aberdeen      2657832        United Kingdom
# 2     Abidjan      2293538         Cote d'Ivoire
# 3   Abu Dhabi       292968  United Arab Emirates
# 4       Abuja      2352778               Nigeria
#
#    Residential EUI (kWh/m2/year)  Non-residential EUI (kWh/m2/year)
# 0                      59.096065                         112.778867
# 1                     231.302877                         259.832393
# 2                      73.830819                         105.622137
# 3                     128.447899                         226.725457
# 4                      63.955819                         103.009079

# %%
df = pd.merge(
    countries_df, eui_df, left_on="geonameid", right_on="Geonames ID", how="inner"
)
# Out:
#      geonameid          name     asciiname  \
# 0       292968     Abu Dhabi     Abu Dhabi
# 1      1138958         Kabul         Kabul
# 2      3183875        Tirana        Tirana
# 3       616052       Yerevan       Yerevan
# 4      2240449        Luanda        Luanda
# ..         ...           ...           ...
# 477    1018725  Bloemfontein  Bloemfontein
# 478    3369157     Cape Town     Cape Town
# 479     909137        Lusaka        Lusaka
# 480     890299        Harare        Harare
# 481     894701      Bulawayo      Bulawayo
#
#                                         alternatenames  latitude  longitude  \
# 0    A-pu-that-pi,AEbu Saby,AUH,Aboe Dhabi,Abou Dab...  24.45118   54.39696
# 1    Cabool,Caboul,Cabul,Cabura,Cabúl,Caubul,KBL,Ka...  34.52813   69.17233
# 2    TIA,Terana,Theranda,Tiorana,Tiorána,Tiran,Tira...  41.32750   19.81889
# 3    Ayrivan,Djerevan,EVN,Eireavan,Eireaván,Ereban,...  40.18111   44.51361
# 4    LAD,Loanda,Louanda,Louanta,Luand,Luanda,Luanda...  -8.83682   13.23432
# ..                                                 ...       ...        ...
# 477  BFN,Bloemfontein,Blumfantehjn,Blumfonteina,Blu... -29.12107   26.21400
# 478  Altepetl In Cabo,Ar Chab,CPT,Cape Toun,Cape To... -33.92584   18.42322
# 479  LUN,Lousaka,Louzaka,Lusaca,Lusak,Lusaka,Lusako... -15.40669   28.28713
# 480  Arare,Charare,HRE,Harare,Hararensis Urbs,Harar... -17.82772   31.05337
# 481  BUQ,Bulavajas,Bulavajo,Bulavejo,Bulawayo,bu la... -20.15000   28.58333
#
#     feature class feature code iso alpha 2  cc2  ... population elevation  \
# 0               P         PPLC          AE  NaN  ...    1807000       NaN
# 1               P         PPLC          AF  NaN  ...    4434550       NaN
# 2               P         PPLC          AL  NaN  ...     418495       NaN
# 3               P         PPLC          AM  NaN  ...    1093485       NaN
# 4               P         PPLC          AO  NaN  ...    2776168       NaN
# ..            ...          ...         ...  ...  ...        ...       ...
# 477             P         PPLA          ZA  NaN  ...     556000       NaN
# 478             P         PPLA          ZA  NaN  ...    4710000       NaN
# 479             P         PPLC          ZM  NaN  ...    1267440       NaN
# 480             P         PPLC          ZW  NaN  ...    1542813       NaN
# 481             P         PPLA          ZW  NaN  ...    1200337       NaN
#
#       dem             timezone  modification date          City  Geonames ID  \
# 0       6           Asia/Dubai         2024-03-27     Abu Dhabi       292968
# 1    1798           Asia/Kabul         2024-09-05         Kabul      1138958
# 2     113        Europe/Tirane         2023-01-01        Tirana      3183875
# 3     994         Asia/Yerevan         2023-11-13       Yerevan       616052
# 4      73        Africa/Luanda         2024-03-26        Luanda      2240449
# ..    ...                  ...                ...           ...          ...
# 477  1396  Africa/Johannesburg         2022-08-16  Bloemfontein      1018725
# 478    25  Africa/Johannesburg         2024-03-27     Cape Town      3369157
# 479  1277        Africa/Lusaka         2019-09-05        Lusaka       909137
# 480  1494        Africa/Harare         2019-09-05        Harare       890299
# 481  1348        Africa/Harare         2023-02-24      Bulawayo       894701
#
#                   Country Residential EUI (kWh/m2/year)  \
# 0    United Arab Emirates                    128.447899
# 1             Afghanistan                    213.167026
# 2                 Albania                    133.717672
# 3                 Armenia                    198.865302
# 4                  Angola                     65.343750
# ..                    ...                           ...
# 477          South Africa                     78.735991
# 478          South Africa                     71.455819
# 479                Zambia                     75.533405
# 480              Zimbabwe                     69.613147
# 481              Zimbabwe                     77.230603
#
#     Non-residential EUI (kWh/m2/year)
# 0                          226.725457
# 1                          144.395840
# 2                          101.873579
# 3                          132.124738
# 4                          104.311100
# ..                                ...
# 477                        106.046441
# 478                        104.301427
# 479                        105.500787
# 480                        102.108799
# 481                        103.237434
#
# [482 rows x 24 columns]

# %%
df = df[["geonameid","latitude","longitude"]]

# %%
df
# Out:
#      geonameid  latitude  longitude
# 0       292968  24.45118   54.39696
# 1      1138958  34.52813   69.17233
# 2      3183875  41.32750   19.81889
# 3       616052  40.18111   44.51361
# 4      2240449  -8.83682   13.23432
# ..         ...       ...        ...
# 477    1018725 -29.12107   26.21400
# 478    3369157 -33.92584   18.42322
# 479     909137 -15.40669   28.28713
# 480     890299 -17.82772   31.05337
# 481     894701 -20.15000   28.58333
#
# [482 rows x 3 columns]
